# %%
import numpy as np
import matplotlib.pyplot as plt
vs = np.load('adds_vs_dj.npy')

# %%
len(vs)
vs
# Out:
# array([1699.33052195, 1212.64793591, 1570.3097785 , 1373.96951675,
#         422.26576735,  271.19617015, 1919.39641402,  346.75461443,
#        2163.86757614,  706.67290218, 1145.93155706,  152.74754536,
#        1812.26179872,  174.6551843 , 1547.15333754,  238.46284077,
#        1381.23134591, 1398.29268878,  680.50150255, 1803.72386685,
#        3526.67913916, 1820.7614677 ,  382.6924515 , 2049.92950515,
#        1705.85654102,  296.57922919, 1739.43587583, 2015.5736039 ,
#         864.64694838,  504.91421214,  148.73739565,  791.59526003,
#        1219.60475974, 1985.06699102,  588.86987066, 2572.56359385,
#         596.97583141, 1062.9200361 ,  469.79290134,  612.28221555,
#         288.21421843, 2326.4506918 ,  247.48920456,  881.68968865,
#        3063.79842098,  326.3715802 , 1297.88727239,  226.04195828,
#        1587.45051853,  683.72315657,  618.53434926,  652.54624488])

# %%
plt.hist(vs, bins=100)
plt.xlabel("Speed up (times)")
plt.ylabel("Numbers")
plt.savefig('cmp.jpg',dpi=400)
